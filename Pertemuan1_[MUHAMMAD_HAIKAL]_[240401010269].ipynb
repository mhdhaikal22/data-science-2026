# %% [markdown]
# <a href="https://colab.research.google.com/github/mhdhaikal22/data-science-2026/blob/main/Pertemuan1_%5BMUHAMMAD_HAIKAL%5D_%5B240401010269%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan 1 - Pengenalan Data Science
#
# **Nama:** Muhammad Haikal
# **NIM:** 240401010269
# **Kelas:** IF401

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama      = "Muhammad Haikal"
angkatan  = 2025
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List dan Perulangan
tools = ["Phyton", "Google Colab", "Jupyter Notebook", "Github"]
for i, tool in enumerate(tools, 1):
    print(f"  {i}.{tool}")

# SEL 4: Fungsi Sederhana
def perkenalan (nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Muhammad Haikal","Informatika",2025))
# Out:
# Hello, Data Science!
# Halo, Muhammad Haikal angkatan 2025!
#   1.Phyton
#   2.Google Colab
#   3.Jupyter Notebook
#   4.Github
# Muhammad Haikal | Informatika | 2025

# %% [markdown]
# ## Kesimpulan
#
# Pada praktikum ini saya mempelajari dasar-dasar pemrograman Python sebagai langkah awal dalam mempelajari Data Science. Saya memahami cara menampilkan output, menggunakan variabel dan tipe data dasar, membuat list, melakukan perulangan (loop), serta membuat fungsi sederhana untuk mengolah data.
#
# Temuan utama dari praktikum ini adalah bahwa Python memiliki sintaks yang sederhana dan mudah dipahami, sehingga sangat cocok digunakan sebagai bahasa pemrograman dalam Data Science. Praktikum ini masih berfokus pada konsep dasar, sehingga belum mencakup pengolahan maupun analisis data. Oleh karena itu, materi pada pertemuan selanjutnya diperlukan untuk memahami penerapan Python dalam analisis data secara lebih mendalam.
